# %%
' Mr. Kim '.str.extract(' ([A-Za-z]+)\\.', expand=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ' Mr. Kim '.str.extract(' ([A-Za-z]+)\\.', expand=False)
#
# AttributeError: 'str' object has no attribute 'str'
